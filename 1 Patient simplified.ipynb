# %%
#Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Dataframe with pandas
df = pd.read_csv('../Python/Data/One Patient.CSV')

# %%
df.head()
# Out:
#               id          event_descr                     event_attr1  \
# 0  ID10010854159      RX Claim - Paid                      BIGUANIDES
# 1  ID10010854159      RX Claim - Paid  BETA BLOCKERS CARDIO-SELECTIVE
# 2  ID10010854159  RX Claim - Rejected              DENY DUE TO ERRORS
# 3  ID10010854159      RX Claim - Paid                FLUOROQUINOLONES
# 4  ID10010854159      RX Claim - Paid    HMG COA REDUCTASE INHIBITORS
#
#                                event_attr2       event_attr3  \
# 0                                      NaN                 5
# 1                                      NaN                 5
# 2  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS  NO DUAL COVERAGE
# 3                                      NaN               5.8
# 4                                      NaN                13
#
#         event_attr4         event_attr5         event_attr6  event_attr7  \
# 0              2.35       METFORMIN HCL            DIABETES          NaN
# 1              2.35            ATENOLOL              CARDIO          NaN
# 2  COPAY EXCEPTIONS            ATENOLOL  ATENOLOL TAB 25 MG  781107810.0
# 3              3.15   CIPROFLOXACIN HCL     INF-ANTIBIOTICS          NaN
# 4             10.35  PRAVASTATIN SODIUM              CARDIO          NaN
#
#                                  event_attr8  event_attr9  event_attr10  Days  \
# 0                   METFORMIN HCL TAB 500 MG         2.65    27250050.0  -664
# 1                         ATENOLOL TAB 25 MG         2.65    33200020.0  -659
# 2                                         90         5.00           NaN  -659
# 3  CIPROFLOXACIN HCL TAB 500 MG (BASE EQUIV)         2.65     5000020.0  -646
# 4               PRAVASTATIN SODIUM TAB 20 MG         2.65    39400065.0  -646
#
#    PAY_DAY_SUPPLY_CNT  PAYABLE_QTY  MME DRUG_TYPE Specialty Specialty2  \
# 0                 NaN          NaN  NaN       NaN       NaN        NaN
# 1                 NaN          NaN  NaN       NaN       NaN        NaN
# 2                 NaN          NaN  NaN       NaN       NaN        NaN
# 3                 NaN          NaN  NaN       NaN       NaN        NaN
# 4                 NaN          NaN  NaN       NaN       NaN        NaN
#
#   Specialty3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df.drop(df.columns[[0,19]], axis = 1 )
# Out:
#               event_descr                                        event_attr1  \
# 0         RX Claim - Paid                                         BIGUANIDES
# 1         RX Claim - Paid                     BETA BLOCKERS CARDIO-SELECTIVE
# 2     RX Claim - Rejected                                 DENY DUE TO ERRORS
# 3         RX Claim - Paid                                   FLUOROQUINOLONES
# 4         RX Claim - Paid                       HMG COA REDUCTASE INHIBITORS
# 5         RX Claim - Paid              THIAZIDES AND THIAZIDE-LIKE DIURETICS
# 6         RX Claim - Paid                                         BIGUANIDES
# 7        Fully Paid Claim               ALLERGIC RHINITIS, CAUSE UNSPECIFIED
# 8     RX Claim - New Drug                                             415500
# 9         RX Claim - Paid                      ANTIHISTAMINES - NON-SEDATING
# 10    Inbound Call by Mbr                                             CLAIMS
# 11   Inbound Call by Prov                                             CLAIMS
# 12    Inbound Call by Mbr                                             CLAIMS
# 13    Inbound Call by Mbr                                           PROVIDER
# 14    Inbound Call by Mbr                                 PLAN OPTION CHANGE
# 15        RX Claim - Paid                                         BIGUANIDES
# 16        RX Claim - Paid                       HMG COA REDUCTASE INHIBITORS
# 17       Fully Paid Claim                 UNSPECIFIED ESSENTIAL HYPERTENSION
# 18       Fully Paid Claim                 UNSPECIFIED ESSENTIAL HYPERTENSION
# 19    RX Claim - Rejected                                 DENY DUE TO ERRORS
# 20    RX Claim - Rejected                                 DENY DUE TO ERRORS
# 21    RX Claim - Rejected                                 DENY DUE TO ERRORS
# 22    RX Claim - Rejected                                 DENY DUE TO ERRORS
# 23       Fully Paid Claim        URINARY TRACT INFECTION, SITE NOT SPECIFIED
# 24        RX Claim - Paid                     BETA BLOCKERS CARDIO-SELECTIVE
# 25        RX Claim - Paid                                         BIGUANIDES
# 26        RX Claim - Paid                                   FLUOROQUINOLONES
# 27        RX Claim - Paid              THIAZIDES AND THIAZIDE-LIKE DIURETICS
# 28    Inbound Call by Mbr                                           PROVIDER
# 29        RX Claim - Paid                                         BIGUANIDES
# ..                    ...                                                ...
# 324   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 325   RX Claim - New Drug                                             169900
# 326   RX Claim - New Drug                                             659910
# 327       RX Claim - Paid                ANTI-INFECTIVE MISC. - COMBINATIONS
# 328       RX Claim - Paid                     BETA BLOCKERS CARDIO-SELECTIVE
# 329       RX Claim - Paid                                OPIOID COMBINATIONS
# 330       RX Claim - Paid                        DIRECT FACTOR XA INHIBITORS
# 331       RX Claim - Paid                               GLUCOCORTICOSTEROIDS
# 332   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 333   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 334   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 335       RX Claim - Paid                           CALCIUM CHANNEL BLOCKERS
# 336   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 337       RX Claim - Paid                        DIRECT FACTOR XA INHIBITORS
# 338   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 339   RX Claim - Rejected                                           REVERSAL
# 340      Fully Paid Claim  ENCOUNTER FOR SCREENING MAMMOGRAM FOR MALIGNAN...
# 341      Fully Paid Claim  ENCOUNTER FOR SCREENING MAMMOGRAM FOR MALIGNAN...
# 342       RX Claim - Paid                     BETA BLOCKERS CARDIO-SELECTIVE
# 343   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 344       RX Claim - Paid                        DIRECT FACTOR XA INHIBITORS
# 345       RX Claim - Paid                                    RECTAL STEROIDS
# 346       RX Claim - Paid                       HMG COA REDUCTASE INHIBITORS
# 347   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 348      Fully Paid Claim                      ENDOTHELIAL CORNEAL DYSTROPHY
# 349   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 350   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 351       RX Claim - Paid                        DIRECT FACTOR XA INHIBITORS
# 352   RX Claim - Rejected                                 DENY DUE TO ERRORS
# 353   RX Claim - Rejected                                 DENY DUE TO ERRORS
#
#                                  event_attr2                    event_attr3  \
# 0                                        NaN                              5
# 1                                        NaN                              5
# 2    SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 3                                        NaN                            5.8
# 4                                        NaN                             13
# 5                                        NaN                              5
# 6                                        NaN                              5
# 7                                     OFFICE                            100
# 8              ANTIHISTAMINES - NON-SEDATING      LEVOCETIRIZINE DIHYDROCHL
# 9                                        NaN                            8.2
# 10                              CLAIM DENIED     TRANSFERRED TO MEDICAL CCR
# 11                             CLAIMS STATUS                       FAX SENT
# 12             MEMBER RESPONSIBILITY/BENEFIT                EDUCATED CALLER
# 13                              VERIFICATION            IN NETWORK PROVIDER
# 14                                   FSB/OSB  TRANSFERRED TO LICENSED AGENT
# 15                                       NaN                              5
# 16                                       NaN                             13
# 17             ON CAMPUS-HOSPITAL OUTPATIENT                            312
# 18                                    OFFICE                            100
# 19   SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 20   SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 21   SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 22   SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 23                                    OFFICE                            100
# 24                                       NaN                              5
# 25                                       NaN                              5
# 26                                       NaN                              5
# 27                                       NaN                              5
# 28         PHYSICIAN FINDER/DIRECTORY ISSUES                  EDUCATED USER
# 29                                       NaN                              5
# ..                                       ...                            ...
# 324  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 325      ANTI-INFECTIVE MISC. - COMBINATIONS      SULFAMETHOXAZOLE/TRIMETHO
# 326                      OPIOID COMBINATIONS          ACETAMINOPHEN/CODEINE
# 327                                      NaN                              5
# 328                                      NaN                              5
# 329                                      NaN                              5
# 330                                      NaN                         209.36
# 331                                      NaN                              5
# 332  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 333  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 334  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 335                                      NaN                           68.5
# 336  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 337                                      NaN                         209.36
# 338  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 339  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 340            ON CAMPUS-HOSPITAL OUTPATIENT                          411.5
# 341            ON CAMPUS-HOSPITAL OUTPATIENT                             99
# 342                                      NaN                              5
# 343  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 344                                      NaN                         209.36
# 345                                      NaN                           45.1
# 346                                      NaN                             16
# 347  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 348                                   OFFICE                            319
# 349  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 350  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 351                                      NaN                         417.73
# 352  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
# 353  SYMPTOMS, SIGNS, ILL DEFINED CONDITIONS               NO DUAL COVERAGE
#
#           event_attr4                event_attr5  \
# 0                2.35              METFORMIN HCL
# 1                2.35                   ATENOLOL
# 2    COPAY EXCEPTIONS                   ATENOLOL
# 3                3.15          CIPROFLOXACIN HCL
# 4               10.35         PRAVASTATIN SODIUM
# 5                2.35        HYDROCHLOROTHIAZIDE
# 6                2.35              METFORMIN HCL
# 7                   0                      67.99
# 8                 105                RESPIRATORY
# 9                5.55  LEVOCETIRIZINE DIHYDROCHL
# 10                CCP                 TUCSON, AZ
# 11                CCP             CINCINNATI, OH
# 12                CCP                 TUCSON, AZ
# 13                CCP                 TUCSON, AZ
# 14                CCP                      X, KY
# 15               2.35              METFORMIN HCL
# 16              10.35         PRAVASTATIN SODIUM
# 17              28.11                      13.58
# 18                  0                      67.99
# 19   COPAY EXCEPTIONS        HYDROCHLOROTHIAZIDE
# 20   COPAY EXCEPTIONS    METFORMIN HYDROCHLORIDE
# 21   COPAY EXCEPTIONS         PRAVASTATIN SODIUM
# 22   COPAY EXCEPTIONS                  VITAMIN D
# 23                  0                      67.99
# 24               2.35                   ATENOLOL
# 25               2.35              METFORMIN HCL
# 26               2.35          CIPROFLOXACIN HCL
# 27               2.35        HYDROCHLOROTHIAZIDE
# 28                CCP                      X, KY
# 29               2.35              METFORMIN HCL
# ..                ...                        ...
# 324  COPAY EXCEPTIONS             HYDROCORTISONE
# 325               104      OTHER ANTI INFECTIVES
# 326               102                       PAIN
# 327              1.65  SULFAMETHOXAZOLE/TRIMETHO
# 328              1.65                   ATENOLOL
# 329              4.45      ACETAMINOPHEN/CODEINE
# 330            205.16                    ELIQUIS
# 331              4.45                 PREDNISONE
# 332  COPAY EXCEPTIONS                   ATENOLOL
# 333  COPAY EXCEPTIONS           DILTIAZEM HCL ER
# 334  COPAY EXCEPTIONS         PRAVASTATIN SODIUM
# 335             65.15                  CARTIA XT
# 336  COPAY EXCEPTIONS           DILTIAZEM HCL ER
# 337            205.16                    ELIQUIS
# 338  COPAY EXCEPTIONS                   ATENOLOL
# 339  COPAY EXCEPTIONS         PRAVASTATIN SODIUM
# 340             110.7                          0
# 341              64.9                          0
# 342              1.65                   ATENOLOL
# 343  COPAY EXCEPTIONS                   ATENOLOL
# 344            205.16                    ELIQUIS
# 345             41.75              PROCTOZONE-HC
# 346             12.65         PRAVASTATIN SODIUM
# 347  COPAY EXCEPTIONS                   ATENOLOL
# 348             53.39                         45
# 349  COPAY EXCEPTIONS         PRAVASTATIN SODIUM
# 350  COPAY EXCEPTIONS         PRAVASTATIN SODIUM
# 351            409.38                    ELIQUIS
# 352  COPAY EXCEPTIONS                   ATENOLOL
# 353  COPAY EXCEPTIONS                  CARTIA XT
#
#                                        event_attr6   event_attr7  \
# 0                                         DIABETES           NaN
# 1                                           CARDIO           NaN
# 2                               ATENOLOL TAB 25 MG  7.811078e+08
# 3                                  INF-ANTIBIOTICS           NaN
# 4                                           CARDIO           NaN
# 5                                           CARDIO           NaN
# 6                                         DIABETES           NaN
# 7                                              NaN           NaN
# 8                                              NaN           NaN
# 9                                      RESPIRATORY           NaN
# 10                                             NaN           NaN
# 11                                             NaN           NaN
# 12                                             NaN           NaN
# 13                                             NaN           NaN
# 14                                             NaN           NaN
# 15                                        DIABETES           NaN
# 16                                          CARDIO           NaN
# 17                                             NaN           NaN
# 18                                             NaN           NaN
# 19                   HYDROCHLOROTHIAZIDE TAB 25 MG  6.033856e+08
# 20                        METFORMIN HCL TAB 500 MG  5.766404e+10
# 21                    PRAVASTATIN SODIUM TAB 20 MG  7.815233e+08
# 22                   ERGOCALCIFEROL CAP 50000 UNIT  5.011110e+10
# 23                                             NaN           NaN
# 24                                          CARDIO           NaN
# 25                                        DIABETES           NaN
# 26                                 INF-ANTIBIOTICS           NaN
# 27                                          CARDIO           NaN
# 28                                             NaN           NaN
# 29                                        DIABETES           NaN
# ..                                             ...           ...
# 324               HYDROCORTISONE RECTAL CREAM 2.5%  5.300200e+10
# 325                                            NaN           NaN
# 326                                            NaN           NaN
# 327                          OTHER ANTI INFECTIVES           NaN
# 328                                         CARDIO           NaN
# 329                                           PAIN           NaN
# 330                                          OTHER           NaN
# 331                                   OTH-STEROIDS           NaN
# 332                             ATENOLOL TAB 25 MG  7.811078e+08
# 333  DILTIAZEM HCL COATED BEADS TAB ER 24HR 300 MG  6.868207e+10
# 334                   PRAVASTATIN SODIUM TAB 20 MG  6.050502e+10
# 335                                         CARDIO           NaN
# 336  DILTIAZEM HCL COATED BEADS TAB ER 24HR 300 MG  6.868207e+10
# 337                                          OTHER           NaN
# 338                             ATENOLOL TAB 25 MG  7.811078e+08
# 339                   PRAVASTATIN SODIUM TAB 20 MG  6.050502e+10
# 340                                            NaN           NaN
# 341                                            NaN           NaN
# 342                                         CARDIO           NaN
# 343                             ATENOLOL TAB 25 MG  7.811078e+08
# 344                                          OTHER           NaN
# 345                                   OTH-STEROIDS           NaN
# 346                                         CARDIO           NaN
# 347                             ATENOLOL TAB 25 MG  7.811078e+08
# 348                                            NaN           NaN
# 349                   PRAVASTATIN SODIUM TAB 20 MG  6.050502e+10
# 350                   PRAVASTATIN SODIUM TAB 20 MG  6.050502e+10
# 351                                          OTHER           NaN
# 352                             ATENOLOL TAB 25 MG  7.811078e+08
# 353  DILTIAZEM HCL COATED BEADS CAP ER 24HR 300 MG  6.203706e+10
#
#                                        event_attr8  event_attr9  event_attr10  \
# 0                         METFORMIN HCL TAB 500 MG         2.65    27250050.0
# 1                               ATENOLOL TAB 25 MG         2.65    33200020.0
# 2                                               90         5.00           NaN
# 3        CIPROFLOXACIN HCL TAB 500 MG (BASE EQUIV)         2.65     5000020.0
# 4                     PRAVASTATIN SODIUM TAB 20 MG         2.65    39400065.0
# 5                    HYDROCHLOROTHIAZIDE TAB 25 MG         2.65    37600040.0
# 6                         METFORMIN HCL TAB 500 MG         2.65    27250050.0
# 7                                              NaN          NaN           NaN
# 8          LEVOCETIRIZINE DIHYDROCHLORIDE TAB 5 MG         2.65    41550027.0
# 9          LEVOCETIRIZINE DIHYDROCHLORIDE TAB 5 MG         2.65    41550027.0
# 10                                             NaN          NaN           NaN
# 11                                             NaN          NaN           NaN
# 12                                             NaN          NaN           NaN
# 13                                             NaN          NaN           NaN
# 14                                             NaN          NaN           NaN
# 15                        METFORMIN HCL TAB 500 MG         2.65    27250050.0
# 16                    PRAVASTATIN SODIUM TAB 20 MG         2.65    39400065.0
# 17                                             NaN          NaN           NaN
# 18                                             NaN          NaN           NaN
# 19                                              30         4.00           NaN
# 20                                              30         4.00           NaN
# 21                                              30         7.00           NaN
# 22                                              84        11.20           NaN
# 23                                             NaN          NaN           NaN
# 24                              ATENOLOL TAB 25 MG         2.65    33200020.0
# 25                        METFORMIN HCL TAB 500 MG         2.65    27250050.0
# 26       CIPROFLOXACIN HCL TAB 500 MG (BASE EQUIV)         2.65     5000020.0
# 27                   HYDROCHLOROTHIAZIDE TAB 25 MG         2.65    37600040.0
# 28                                             NaN          NaN           NaN
# 29                        METFORMIN HCL TAB 500 MG         2.65    27250050.0
# ..                                             ...          ...           ...
# 324                                             10         0.01           NaN
# 325   SULFAMETHOXAZOLE-TRIMETHOPRIM TAB 800-160 MG         3.35    16990002.0
# 326         ACETAMINOPHEN W/ CODEINE TAB 300-30 MG         0.55    65991002.0
# 327   SULFAMETHOXAZOLE-TRIMETHOPRIM TAB 800-160 MG         3.35    16990002.0
# 328                             ATENOLOL TAB 25 MG         3.35    33200020.0
# 329         ACETAMINOPHEN W/ CODEINE TAB 300-30 MG         0.55    65991002.0
# 330                              APIXABAN TAB 5 MG         4.20    83370010.0
# 331                           PREDNISONE TAB 20 MG         0.55    22100045.0
# 332                                             60         5.00           NaN
# 333                                             90       285.00           NaN
# 334                                             60        14.00           NaN
# 335  DILTIAZEM HCL COATED BEADS CAP ER 24HR 300 MG         3.35    34000010.0
# 336                                             90       285.00           NaN
# 337                              APIXABAN TAB 5 MG         4.20    83370010.0
# 338                                             60         5.00           NaN
# 339                                             60         3.35           NaN
# 340                                            NaN          NaN           NaN
# 341                                            NaN          NaN           NaN
# 342                             ATENOLOL TAB 25 MG         3.35    33200020.0
# 343                                             60         5.00           NaN
# 344                              APIXABAN TAB 5 MG         4.20    83370010.0
# 345               HYDROCORTISONE RECTAL CREAM 2.5%         3.35    89100010.0
# 346                   PRAVASTATIN SODIUM TAB 20 MG         3.35    39400065.0
# 347                                             60         5.00           NaN
# 348                                            NaN          NaN           NaN
# 349                                             60        14.00           NaN
# 350                                             90        21.00           NaN
# 351                              APIXABAN TAB 5 MG         8.35    83370010.0
# 352                                             60         5.00           NaN
# 353                                             90        51.00           NaN
#
#      Days  PAY_DAY_SUPPLY_CNT  PAYABLE_QTY   MME DRUG_TYPE  \
# 0    -664                 NaN          NaN   NaN       NaN
# 1    -659                 NaN          NaN   NaN       NaN
# 2    -659                 NaN          NaN   NaN       NaN
# 3    -646                 NaN          NaN   NaN       NaN
# 4    -646                 NaN          NaN   NaN       NaN
# 5    -644                 NaN          NaN   NaN       NaN
# 6    -631                 NaN          NaN   NaN       NaN
# 7    -630                 NaN          NaN   NaN       NaN
# 8    -630                 NaN          NaN   NaN       NaN
# 9    -630                 NaN          NaN   NaN       NaN
# 10   -629                 NaN          NaN   NaN       NaN
# 11   -629                 NaN          NaN   NaN       NaN
# 12   -623                 NaN          NaN   NaN       NaN
# 13   -623                 NaN          NaN   NaN       NaN
# 14   -617                 NaN          NaN   NaN       NaN
# 15   -598                 NaN          NaN   NaN       NaN
# 16   -598                 NaN          NaN   NaN       NaN
# 17   -595                 NaN          NaN   NaN       NaN
# 18   -588                 NaN          NaN   NaN       NaN
# 19   -588                 NaN          NaN   NaN       NaN
# 20   -588                 NaN          NaN   NaN       NaN
# 21   -588                 NaN          NaN   NaN       NaN
# 22   -588                 NaN          NaN   NaN       NaN
# 23   -568                 NaN          NaN   NaN       NaN
# 24   -568                 NaN          NaN   NaN       NaN
# 25   -568                 NaN          NaN   NaN       NaN
# 26   -568                 NaN          NaN   NaN       NaN
# 27   -554                 NaN          NaN   NaN       NaN
# 28   -534                 NaN          NaN   NaN       NaN
# 29   -534                 NaN          NaN   NaN       NaN
# ..    ...                 ...          ...   ...       ...
# 324   705                 NaN          NaN   NaN       NaN
# 325   706                 NaN          NaN   NaN       NaN
# 326   706                 5.0         14.0  12.6        IR
# 327   706                 NaN          NaN   NaN       NaN
# 328   706                 NaN          NaN   NaN       NaN
# 329   706                 5.0         14.0  12.6        IR
# 330   711                 NaN          NaN   NaN       NaN
# 331   711                 NaN          NaN   NaN       NaN
# 332   711                 NaN          NaN   NaN       NaN
# 333   711                 NaN          NaN   NaN       NaN
# 334   711                 NaN          NaN   NaN       NaN
# 335   718                 NaN          NaN   NaN       NaN
# 336   718                 NaN          NaN   NaN       NaN
# 337   736                 NaN          NaN   NaN       NaN
# 338   736                 NaN          NaN   NaN       NaN
# 339   736                 NaN          NaN   NaN       NaN
# 340   740                 NaN          NaN   NaN       NaN
# 341   740                 NaN          NaN   NaN       NaN
# 342   756                 NaN          NaN   NaN       NaN
# 343   756                 NaN          NaN   NaN       NaN
# 344   757                 NaN          NaN   NaN       NaN
# 345   757                 NaN          NaN   NaN       NaN
# 346   762                 NaN          NaN   NaN       NaN
# 347   762                 NaN          NaN   NaN       NaN
# 348   775                 NaN          NaN   NaN       NaN
# 349   775                 NaN          NaN   NaN       NaN
# 350   775                 NaN          NaN   NaN       NaN
# 351   777                 NaN          NaN   NaN       NaN
# 352   777                 NaN          NaN   NaN       NaN
# 353   777                 NaN          NaN   NaN       NaN
#
#                     Specialty Specialty2
# 0                         NaN        NaN
# 1                         NaN        NaN
# 2                         NaN        NaN
# 3                         NaN        NaN
# 4                         NaN        NaN
# 5                         NaN        NaN
# 6                         NaN        NaN
# 7                         NaN        NaN
# 8                         NaN        NaN
# 9                         NaN        NaN
# 10                        NaN        NaN
# 11                        NaN        NaN
# 12                        NaN        NaN
# 13                        NaN        NaN
# 14                        NaN        NaN
# 15                        NaN        NaN
# 16                        NaN        NaN
# 17                        NaN        NaN
# 18                        NaN        NaN
# 19                        NaN        NaN
# 20                        NaN        NaN
# 21                        NaN        NaN
# 22                        NaN        NaN
# 23                        NaN        NaN
# 24                        NaN        NaN
# 25                        NaN        NaN
# 26                        NaN        NaN
# 27                        NaN        NaN
# 28                        NaN        NaN
# 29                        NaN        NaN
# ..                        ...        ...
# 324                       NaN        NaN
# 325                       NaN        NaN
# 326  Dentist General Practice    Dentist
# 327                       NaN        NaN
# 328                       NaN        NaN
# 329  Dentist General Practice    Dentist
# 330                       NaN        NaN
# 331                       NaN        NaN
# 332                       NaN        NaN
# 333                       NaN        NaN
# 334                       NaN        NaN
# 335                       NaN        NaN
# 336                       NaN        NaN
# 337                       NaN        NaN
# 338                       NaN        NaN
# 339                       NaN        NaN
# 340                       NaN        NaN
# 341                       NaN        NaN
# 342                       NaN        NaN
# 343                       NaN        NaN
# 344                       NaN        NaN
# 345                       NaN        NaN
# 346                       NaN        NaN
# 347                       NaN        NaN
# 348                       NaN        NaN
# 349                       NaN        NaN
# 350                       NaN        NaN
# 351                       NaN        NaN
# 352                       NaN        NaN
# 353                       NaN        NaN
#
# [354 rows x 18 columns]

# %%
#Qualifying Events start at Day 0, easy to find opioid events via MME
after180 = df[df['MME'].notnull() & (df['Days']>=0)]
#Define series to add
days = after180.loc[:,'Days']
add = after180.loc[:,'PAY_DAY_SUPPLY_CNT']
print (days, add)
# Out:
# 193      0
# 194      0
# 326    706
# 329    706
# Name: Days, dtype: int64 193    5.0
# 194    5.0
# 326    5.0
# 329    5.0
# Name: PAY_DAY_SUPPLY_CNT, dtype: float64

# %%
#Making list
atrisk = []
#a is a pointer to the first date of 6 month period
a = 0
i = 0
#generalizable loop
while i in range(len(days)):
#i is current event
    currentday= days.iloc[i]
    nextday = days.iloc[i+1]
    fromcurrent180 = days.iloc[i] + 180
    currentsupply = days.iloc[i] + add.iloc[i]
    nextsupply = days.iloc[i+1] + add.iloc[i+1]
    month6begin = days.iloc[a]
    month6end = days.iloc[a] + 180
    begin= str(days.iloc[a])
    end= str(days.iloc[a]+180)
    overlap = 0
    over180 = 0 
    print('6-month window: ' + begin + ' - ' + end)
    print('6month window event:' + str(a))
    print('Currently it is event:' + str(i) + ' Day:' + str(days.iloc[i]) + ' Supply Count: ' + str(add.iloc[i]))
    
#Remove days over 180 days, ignore if not in 6 month window
    if (nextsupply >= fromcurrent180) & (nextday < month6end): 
        over180 = fromcurrent180 - nextsupply
#Remove overlapping days
    print('over180: ' + str(over180))
    if (currentday < month6end) & (currentsupply > days.iloc[i+1]):
        overlap = currentsupply - nextday
    print('overlap: ' + str(overlap))
#90% of 6 month period
    Value = add.iloc[i] - overlap - over180
    print('Value: ' + str(Value))
    if Value >= 162:
        atrisk.append(True)
        break
    else:
        i += 1
        print('Going to event: ' + str(i))
#a goes to next event when 6 month window fails
    if (days.iloc[i] >= month6end) & (Value < 162):
        a += 1
        print('Going to next 6-month window: ' + begin + ' - ' + end)
        print('With event: ' + str(a) + ' as beginning of 6 month window')
        print('It was event: ' + str(i)) 
        i = a
        print("And now we're going back to event: " + str(i))
        Value = 0
    if i+1 >= len(days):
        if (nextsupply >= fromcurrent180) & (nextday < month6end): 
            over180 = fromcurrent180 - nextsupply
            Value += add.iloc[i] - overlap
        if Value < 162:
            atrisk.append(False)
            break
print(atrisk)
# Out:
# 6-month window: 0 - 180
# 6month window event:0
# Currently it is event:0 Day:0 Supply Count: 5.0
# over180: 0
# overlap: 5.0
# Value: 0.0
# Going to event: 1
# 6-month window: 0 - 180
# 6month window event:0
# Currently it is event:1 Day:0 Supply Count: 5.0
# over180: 0
# overlap: 0
# Value: 5.0
# Going to event: 2
# Going to next 6-month window: 0 - 180
# With event: 1 as beginning of 6 month window
# It was event: 2
# And now we're going back to event: 1
# 6-month window: 0 - 180
# 6month window event:1
# Currently it is event:1 Day:0 Supply Count: 5.0
# over180: 0
# overlap: 0
# Value: 5.0
# Going to event: 2
# Going to next 6-month window: 0 - 180
# With event: 2 as beginning of 6 month window
# It was event: 2
# And now we're going back to event: 2
# 6-month window: 706 - 886
# 6month window event:2
# Currently it is event:2 Day:706 Supply Count: 5.0
# over180: 0
# overlap: 5.0
# Value: 0.0
# Going to event: 3
# [False]
